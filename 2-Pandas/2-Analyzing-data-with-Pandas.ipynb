# %% [markdown]
# # Analyzing Data with Pandas
# Here, we continue our exploration of the Pandas package. We focus on various ways data stored in dataframes can be analyzed using the package. Specifically, we look at:
# 1. [Calculating and updating fields](#1.-Calculating-and-updating-fields)
# * [Selecting data in a dataframe](#2.-Selecting-data-from-a-dataframe)
#  1. [Selecting single rows, select rows, or row slices using `iloc`](#2a.-Selecting-single-rows,-select-rows,-or-row-slices-using-iloc)
#  1. [Selecting rows and columns using `iloc`](#2b.-Selecting-rows-and-columns-using--iloc)
#  1. [Selecting rows and columns using `loc`](#2c.-Selecting-rows-and-columns-using--loc)
#  1. [Selecting rows based on criteria - using _queries_](#2d.-Selecting-rows-based-on-criteria---using-queries)
#  1. [Selecting rows based on criteria - using _masks_](#2e.-Selecting-rows-based-on-criteria---using-masks)
#  1. [Updating values in selected rows/columns](#2f.-Updating-values-in-selected-rows/columns)
# * [Grouping and aggregating data in a dataframe](#3.-Grouping-data)

# %%
#Import data
import pandas as pd

# %%
#Initial import of surveys dataset
survey_df = pd.read_csv('../data/surveys.csv',
                        index_col='record_id',
                        dtype={'plot_id':'str'})
survey_df.head()
# Out:
#            month  day  year plot_id species_id sex  hindfoot_length  weight
# record_id
# 1              7   16  1977       2         NL   M             32.0     NaN
# 2              7   16  1977       3         NL   M             33.0     NaN
# 3              7   16  1977       2         DM   F             37.0     NaN
# 4              7   16  1977       7         DM   M             36.0     NaN
# 5              7   16  1977       3         DM   M             35.0     NaN

# %% [markdown]
# ## 1. Calculating and updating fields
# A typical operation in dataframes is creating new fields from values in other fields. We'll show this by computing hindfoodt_length (currently in mm) into inches. (25.4 mm per inch...)

# %%
#Create a field of hindfoot length in inches
survey_df['hindfoot_length_in'] = survey_df['hindfoot_length'] / 25.4

#Review the output
survey_df.head()
# Out:
#            month  day  year plot_id species_id sex  hindfoot_length  weight  \
# record_id
# 1              7   16  1977       2         NL   M             32.0     NaN
# 2              7   16  1977       3         NL   M             33.0     NaN
# 3              7   16  1977       2         DM   F             37.0     NaN
# 4              7   16  1977       7         DM   M             36.0     NaN
# 5              7   16  1977       3         DM   M             35.0     NaN
#
#            hindfoot_length_in
# record_id
# 1                    1.259843
# 2                    1.299213
# 3                    1.456693
# 4                    1.417323
# 5                    1.377953

# %% [markdown]
# ► YOU TRY IT:
# * Create a new column "weight_oz" converting weigth (grams) into ounces (28.35 g/oz)

# %%
#Create a field of weight in ounces
survey_df["weight_oz"] = survey_df["weight"] * (1/28.35)

#Review the output
survey_df.tail()
# Out:
#            month  day  year plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 35545         12   31  2002      15         AH  NaN              NaN     NaN
# 35546         12   31  2002      15         AH  NaN              NaN     NaN
# 35547         12   31  2002      10         RM    F             15.0    14.0
# 35548         12   31  2002       7         DO    M             36.0    51.0
# 35549         12   31  2002       5        NaN  NaN              NaN     NaN
#
#            hindfoot_length_in  weight_oz
# record_id
# 35545                     NaN        NaN
# 35546                     NaN        NaN
# 35547                0.590551   0.493827
# 35548                1.417323   1.798942
# 35549                     NaN        NaN

# %% [markdown]
# ## 2. Selecting data from a dataframe
# We often want to isolate specific rows and/or columns of data from our dataframe for further analysis. Pandas offers many ways to do this. Here we'll review these techniques.
#
# ### 2a. Selecting single rows, select rows, or row *slices* using `iloc`
# Recall that dataframes can be considered lists (rows) of lists (columns). As such, we can select specific rows by their **integer index**, either indivdually or in *slices*. This is done using the dataframe's `iloc` method.
#
# Refer to the [Pandas help on `iloc`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html) for more info on this functionality:
# > _**`iloc`** is short for integer location_

# %%
#Fetch the 4th row of data
survey_df.iloc[3]
# Out:
# month                        7
# day                         16
# year                      1977
# plot_id                      7
# species_id                  DM
# sex                          M
# hindfoot_length           36.0
# weight                     NaN
# hindfoot_length_in    1.417323
# weight_oz                  NaN
# Name: 4, dtype: object

# %%
#Fetch the 101st thru 110th rows of data
survey_df.iloc[100:110]
# Out:
#            month  day  year plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 101            8   20  1977       5         DM    F             35.0    46.0
# 102            8   20  1977      23         DM    F             35.0    40.0
# 103            8   20  1977      18         DM    F             35.0    30.0
# 104            8   20  1977      11         DS    M             43.0     NaN
# 105            8   20  1977      19         DM    M             35.0    39.0
# 106            8   20  1977      12         NL  NaN              NaN     NaN
# 107            8   20  1977      18         NL  NaN              NaN     NaN
# 108            8   20  1977      11         PP    M             21.0     NaN
# 109            8   20  1977       6         DM    M             35.0    34.0
# 110            8   20  1977      10         DS  NaN              NaN     NaN
#
#            hindfoot_length_in  weight_oz
# record_id
# 101                  1.377953   1.622575
# 102                  1.377953   1.410935
# 103                  1.377953   1.058201
# 104                  1.692913        NaN
# 105                  1.377953   1.375661
# 106                       NaN        NaN
# 107                       NaN        NaN
# 108                  0.826772        NaN
# 109                  1.377953   1.199295
# 110                       NaN        NaN

# %%
#Fetch the 3rd, 5th, and 10th rows
survey_df.iloc[[2,4,9]]
# Out:
#            month  day  year plot_id species_id sex  hindfoot_length  weight  \
# record_id
# 3              7   16  1977       2         DM   F             37.0     NaN
# 5              7   16  1977       3         DM   M             35.0     NaN
# 10             7   16  1977       6         PF   F             20.0     NaN
#
#            hindfoot_length_in  weight_oz
# record_id
# 3                    1.456693        NaN
# 5                    1.377953        NaN
# 10                   0.787402        NaN

# %% [markdown]
# ### 2b. Selecting rows and columns using  `iloc`
# The `iloc` method can also be used to select columns. Which columns to select are passed as the second parameter in the `iloc` function. Therefore, we need to specify which rows we want to fetch first. If we want to retrieve the selected columns for all rows, we can just pass a "`:`" as the first parameter.

# %%
#Select all rows and the 4th column of the dataset
survey_df.iloc[:,3]
# Out:
# record_id
# 1         2
# 2         3
# 3         2
# 4         7
# 5         3
#          ..
# 35545    15
# 35546    15
# 35547    10
# 35548     7
# 35549     5
# Name: plot_id, Length: 35549, dtype: object

# %%
#Select the first 5 rows and the 4th column of the dataset
survey_df.iloc[:5,3]
# Out:
# record_id
# 1    2
# 2    3
# 3    2
# 4    7
# 5    3
# Name: plot_id, dtype: object

# %% [markdown]
# → ***So you see, selecting subsets is just a matter of messing around with the row/column integer indices and inserting them into the `iloc` method.***

# %% [markdown]
# ### 2c. Selecting rows and columns using  `loc`
# While `iloc` selects rows and columns by their absolute _position_, `loc` selects rows and columns by their _labels_. Yes, each row and column has a label. A column's label is its ***column name***; a row's label is its ***label index*** (not to be confused with its _integer_ index, which is simply its row number).
#
# When Pandas reads in a CSV file, the CSV file determines the column names, but row labels are assigned a sequential numeric value by default. When we read in data into our `surveys_df`, we specified the values inthe `record_id` column to become our index, i.e., our row labels. We can now use these labels to select rows, and combine them with column names to select row/column combinations:

# %%
#Fetch the row with row label of 10
survey_df.loc[10]
# Out:
# month                        7
# day                         16
# year                      1977
# plot_id                      6
# species_id                  PF
# sex                          F
# hindfoot_length           20.0
# weight                     NaN
# hindfoot_length_in    0.787402
# weight_oz                  NaN
# Name: 10, dtype: object

# %%
#Fetch value in the species_id column in the row with row label of 10 
survey_df.loc[10,'species_id']
# Out:
# 'PF'

# %% [markdown]
# Because our dataframe's row index (i.e. its row labels) happens to be numeric, we can fetch slices of values. We can also fetch multiple columns by passing them in as a list.

# %%
#Fetch value in the species_id column in the row with rows with labels between 10 and 20
survey_df.loc[10:20,['species_id','sex']]
# Out:
#           species_id  sex
# record_id
# 10                PF    F
# 11                DS    F
# 12                DM    M
# 13                DM    M
# 14                DM  NaN
# 15                DM    F
# 16                DM    F
# 17                DS    F
# 18                PP    M
# 19                PF  NaN
# 20                DS    F

# %% [markdown]
# ### 2d. Selecting rows based on criteria - using _queries_
# Instead of selecting data by position or by index, we can also query our dataframe for all records meeting specific criteria. In this first example, we'll use the dataframe's `query()` function.

# %%
#Fetch all records from the year 1997 into a new variable
records_1997 = survey_df.query('year == 1997')
records_1997.shape
# Out:
# (2493, 10)

# %%
#Fetch all records from 1997 for female individuals
females_1997 = survey_df.query('year == 1997 & sex == "F"')
females_1997.shape
# Out:
# (1071, 10)

# %% [markdown]
# ### 2e. Selecting rows based on criteria - using _masks_
# Queries are handy, but as more criteria are used, the query statement can get cumbersome. The use of masks provide a somewhat more simplified approach, or at least a more modular approach.
#
# A "mask" is a Python series (i.e. one column of data) with a Boolean values for each row:

# %%
survey_df
# Out:
#            month  day  year plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 1              7   16  1977       2         NL    M             32.0     NaN
# 2              7   16  1977       3         NL    M             33.0     NaN
# 3              7   16  1977       2         DM    F             37.0     NaN
# 4              7   16  1977       7         DM    M             36.0     NaN
# 5              7   16  1977       3         DM    M             35.0     NaN
# ...          ...  ...   ...     ...        ...  ...              ...     ...
# 35545         12   31  2002      15         AH  NaN              NaN     NaN
# 35546         12   31  2002      15         AH  NaN              NaN     NaN
# 35547         12   31  2002      10         RM    F             15.0    14.0
# 35548         12   31  2002       7         DO    M             36.0    51.0
# 35549         12   31  2002       5        NaN  NaN              NaN     NaN
#
#            hindfoot_length_in  weight_oz
# record_id
# 1                    1.259843        NaN
# 2                    1.299213        NaN
# 3                    1.456693        NaN
# 4                    1.417323        NaN
# 5                    1.377953        NaN
# ...                       ...        ...
# 35545                     NaN        NaN
# 35546                     NaN        NaN
# 35547                0.590551   0.493827
# 35548                1.417323   1.798942
# 35549                     NaN        NaN
#
# [35549 rows x 10 columns]

# %%
#Create a mask for all records with hindfeet smaller than 35mm
mask_smallfeet = survey_df['hindfoot_length'] < 35
mask_smallfeet
# Out:
# record_id
# 1         True
# 2         True
# 3        False
# 4        False
# 5        False
#          ...
# 35545    False
# 35546    False
# 35547     True
# 35548    False
# 35549    False
# Name: hindfoot_length, Length: 35549, dtype: bool

# %% [markdown]
# We can now apply this mask to select records where the mask value is true by using it with the `loc` method.

# %%
survey_df.loc[mask_smallfeet]
# Out:
#            month  day  year plot_id species_id sex  hindfoot_length  weight  \
# record_id
# 1              7   16  1977       2         NL   M             32.0     NaN
# 2              7   16  1977       3         NL   M             33.0     NaN
# 6              7   16  1977       1         PF   M             14.0     NaN
# 9              7   16  1977       1         DM   F             34.0     NaN
# 10             7   16  1977       6         PF   F             20.0     NaN
# ...          ...  ...   ...     ...        ...  ..              ...     ...
# 35540         12   31  2002      15         PB   F             26.0    23.0
# 35541         12   31  2002      15         PB   F             24.0    31.0
# 35542         12   31  2002      15         PB   F             26.0    29.0
# 35543         12   31  2002      15         PB   F             27.0    34.0
# 35547         12   31  2002      10         RM   F             15.0    14.0
#
#            hindfoot_length_in  weight_oz
# record_id
# 1                    1.259843        NaN
# 2                    1.299213        NaN
# 6                    0.551181        NaN
# 9                    1.338583        NaN
# 10                   0.787402        NaN
# ...                       ...        ...
# 35540                1.023622   0.811287
# 35541                0.944882   1.093474
# 35542                1.023622   1.022928
# 35543                1.062992   1.199295
# 35547                0.590551   0.493827
#
# [18172 rows x 10 columns]

# %% [markdown]
# What's nice about masks is that we can combine multiple masks. Think of each Boolean value as as on/off switch that determines whether or not the value is added to the final set. We use `&` ["and" switch] to combine switches such that each must be "on", and `|` ["or" switch] to require only one switch to be on.

# %%
#Create a mask of females
mask_male = survey_df['sex'] == 'M'
mask_male

#Create a mask for records colected in April
mask_april = survey_df['month'] == 4

# %%
#Filter records meeting all criteria
data_subset = survey_df.loc[mask_smallfeet & mask_male & mask_april]
data_subset.shape
# Out:
# (790, 10)

# %%
#Filter records meeting any criteria
data_subset = survey_df.loc[mask_smallfeet | mask_male | mask_april]
data_subset.shape
# Out:
# (27550, 10)

# %% [markdown]
# #### ►Knowledge check:
# * Use the `query()` function to select all male individuals with weight greater than 41 g.
#  * What is the median hindfoot length of this population?
# * Perform the same analysis using masks.

# %%
#Extract males weighing more than 41 g - using query
subset = survey_df.query("sex == 'M' and weight > 41")
subset['hindfoot_length'].median()
# Out:
# 36.0

# %%
#Extract males weighing more than 41 g - using masks
mask_weight = survey_df['weight'] > 41
subset_2 = survey_df.loc[mask_male & mask_weight]
subset_2['hindfoot_length'].median()
# Out:
# 36.0

# %% [markdown]
# ### 2f. Updating values in selected rows/columns
# We've learned how to select data in specific rows and columns. Now we'll update those values.
#
# Our dataset has some erroneous data: records occuring on the "31st" day of April (which has only 30 days in it). We'll replace those dates to be the 30th day of April. To do this, we have to select rows where the month is '4' and the day is '31'. And then with those rows selected, we'll update the the values in the day column to be 30.

# %%
#Create masks for day = 30 and month = 4
mask_day = survey_df['day'] == 31
mask_april = survey_df['month'] == 4 
mask_sept = survey_df['month'] == 9

# %% [markdown]
# If we apply the masks, it returns a dataframe of that selection

# %%
#Apply the masks
survey_df.loc[mask_day & (mask_april | mask_sept)]
# Out:
#            month  day  year plot_id species_id  sex  hindfoot_length  weight  \
# record_id
# 30650          4   31  2000       6         PP    F             22.0    19.0
# 30651          4   31  2000       6         PB    M             25.0    32.0
# 30652          4   31  2000       6         PB    F             25.0    30.0
# 30653          4   31  2000       6         PP    M             23.0    20.0
# 30654          4   31  2000       6         PP    M             23.0    24.0
# ...          ...  ...   ...     ...        ...  ...              ...     ...
# 31500          9   31  2000      16         PM    M             17.0    11.0
# 31501          9   31  2000      16         OT    F             20.0     NaN
# 31502          9   31  2000       5        NaN  NaN              NaN     NaN
# 31503          9   31  2000       7        NaN  NaN              NaN     NaN
# 31504          9   31  2000      10        NaN  NaN              NaN     NaN
#
#            hindfoot_length_in  weight_oz
# record_id
# 30650                0.866142   0.670194
# 30651                0.984252   1.128748
# 30652                0.984252   1.058201
# 30653                0.905512   0.705467
# 30654                0.905512   0.846561
# ...                       ...        ...
# 31500                0.669291   0.388007
# 31501                0.787402        NaN
# 31502                     NaN        NaN
# 31503                     NaN        NaN
# 31504                     NaN        NaN
#
# [136 rows x 10 columns]

# %% [markdown]
# We can add a column designation to just get one column with the selected rows:

# %%
#Fetch the just the day column of the filtered rows
survey_df.loc[mask_day & (mask_april | mask_sept), 'day']
# Out:
# record_id
# 30650    31
# 30651    31
# 30652    31
# 30653    31
# 30654    31
#          ..
# 31500    31
# 31501    31
# 31502    31
# 31503    31
# 31504    31
# Name: day, Length: 136, dtype: int64

# %% [markdown]
# Rather than just display to the screen, we can assign and new value to this selection

# %%
#Update the values
survey_df.loc[mask_day & (mask_april | mask_sept), 'day'] = 30

# %% [markdown]
# Check our results...

# %%
#What's the largest value in the day column for records where month = 4
survey_df.query('month == 4 or month == 9')['day'].max()
# Out:
# 30

# %% [markdown]
# With the dates fixed, we can now create a date attribute

# %%
survey_df['date'] = pd.to_datetime(survey_df[['year','month','day']])
survey_df.head()
# Out:
#            month  day  year plot_id species_id sex  hindfoot_length  weight  \
# record_id
# 1              7   16  1977       2         NL   M             32.0     NaN
# 2              7   16  1977       3         NL   M             33.0     NaN
# 3              7   16  1977       2         DM   F             37.0     NaN
# 4              7   16  1977       7         DM   M             36.0     NaN
# 5              7   16  1977       3         DM   M             35.0     NaN
#
#            hindfoot_length_in  weight_oz       date
# record_id
# 1                    1.259843        NaN 1977-07-16
# 2                    1.299213        NaN 1977-07-16
# 3                    1.456693        NaN 1977-07-16
# 4                    1.417323        NaN 1977-07-16
# 5                    1.377953        NaN 1977-07-16

# %% [markdown]
# ## 3. Grouping data
# We often want to calculate summary statistics grouped by subsets or attributes within fields of our data. For example, we might want to calculate the average weight of all individuals per some variable like `species_id`, `plot_id` or `sex`. This is done by Pandas' `group_by()` function.
#
# So let's go through the process of grouping data by sex (a variable without a lot of unique values) and computing mean weight and mean hindfoot length of males vs females.

# %% [markdown]
# First, some review:
# * We can calculate summary statistics for **all** records in a single column using the syntax below:

# %%
survey_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %% [markdown]
# * We can also extract each single metric separately if we wish:

# %%
print(" Min: ", survey_df['weight'].min())
print(" Max: ", survey_df['weight'].max())
print(" Mean: ", survey_df['weight'].mean())
print(" Std Dev: ", survey_df['weight'].std())
print(" Count: ", survey_df['weight'].count())
# Out:
#  Min:  4.0
#  Max:  280.0
#  Mean:  42.672428212991356
#  Std Dev:  36.63125947458399
#  Count:  32283

# %% [markdown]
# * To summarize by a categorical value, we group the data on that variable. The result of this operation is a new type of object - a Pandas "DataFrameGroupBy" object, which is an intermediate to doing analysis on grouped data.

# %%
#Group the data by unique values in the `sex` field
grouped_data = survey_df.groupby('sex')

#This creates a Panda's "grouped dataframe" object
type(grouped_data)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# * To analyze the grouped dataframe object, we supply an aggregate function like `min()`, `median()`, `count()` etc.

# %%
#Compute the median value of all numeric fields for each group
grouped_data.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:2534, in GroupBy.median.<locals>.<lambda>(x)
#    2461 """
#    2462 Compute median of groups, excluding missing values.
#    2463
#    (...)
#    2530 Freq: MS, dtype: float64
#    2531 """
#    2532 result = self._cython_agg_general(
#    2533     "median",
# -> 2534     alt=lambda x: Series(x, copy=False).median(numeric_only=numeric_only),
#    2535     numeric_only=numeric_only,
#    2536 )
#    2537 return result.__finalize__(self.obj, method="groupby")
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433     )
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#
# TypeError: Cannot convert ['2' '2' '1' ... '15' '15' '10'] to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 #Compute the median value of all numeric fields for each group
# ----> 2 grouped_data.median()
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:2532, in GroupBy.median(self, numeric_only)
#    2459 @final
#    2460 def median(self, numeric_only: bool = False) -> NDFrameT:
#    2461     """
#    2462     Compute median of groups, excluding missing values.
#    2463
#    (...)
#    2530     Freq: MS, dtype: float64
#    2531     """
# -> 2532     result = self._cython_agg_general(
#    2533         "median",
#    2534         alt=lambda x: Series(x, copy=False).median(numeric_only=numeric_only),
#    2535         numeric_only=numeric_only,
#    2536     )
#    2537     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->median,dtype->object]

# %%
# Provide a list of fields if you want to restrict what columns are reported
grouped_data[['hindfoot_length','weight']].median()
# Out:
#      hindfoot_length  weight
# sex
# F               27.0    34.0
# M               34.0    39.0

# %%
# Or, use the describe function to reveal all summary stats for the grouped data
grouped_data['weight'].describe()
# Out:
#        count       mean        std  min   25%   50%   75%    max
# sex
# F    15303.0  42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    16879.0  42.995379  36.184981  4.0  20.0  39.0  49.0  280.0

# %% [markdown]
# ---
# ### <font color='red'>Challenge - Summary Data </font>
# 1. How many recorded individuals are female `F` and how many male `M`

# %%
# Challenge 1: Show the *count* of records, grouped by sex
grouped_data.count()
# Out:
#      month    day   year  plot_id  species_id  hindfoot_length  weight  \
# sex
# F    15690  15690  15690    15690       15690            14894   15303
# M    17348  17348  17348    17348       17348            16476   16879
#
#      hindfoot_length_in  weight_oz   date
# sex
# F                 14894      15303  15690
# M                 16476      16879  17348

# %% [markdown]
# 2. The statement above produces another dataframe. Show just the count of the records in the `weight` field in the resulting dataframe.

# %%
# Challege 2: Just show the 'month' column in the above statement
grouped_data.count()['month']
# Out:
# sex
# F    15690
# M    17348
# Name: month, dtype: int64

# %% [markdown]
# 3. What happens when you group by two columns using the following syntax and then grab mean values:
#  * `grouped_data2 = survey_df.groupby(['plot_id','sex'])`
#  * `grouped_data2.mean()`

# %%
# Challenge 3
grouped_data2 = survey_df.groupby(['plot_id', 'sex'])
grouped_data2.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '...' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 3
#       1 # Challenge 3
#       2 grouped_data2 = survey_df.groupby(['plot_id', 'sex'])
# ----> 3 grouped_data2.mean()
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# 4. Display summary statistics of **hindfood length** values for each **plot id** in your data.
# _HINT: First group data, then extract the one variable you want to summarize, and finally use the `describe` function on that result to compute summary statistics..._

# %%
# Challenge 4

# %% [markdown]
# ### *More complex aggregating functions...*
# We can also supply a **dictionary of aggregating functions** so that each column in the grouped result is aggregated exactly how we want (i.e. instead of computing just the sum or mean of all columns). This dictionary is built by specifying the <u>column name as the key</u> and the <u>aggregate function(s) as the values</u>. Below is an example to aggregate the data by `sex`, computing the minumum and maximum of the `year`, the median of the `hindfoot_length`, and the mean `weight`.

# %%
#Create the aggregate function dictionary
aggFuncs = {
    "year": ['count','min','max'],#compute count, min, and max of the year attribute
    "hindfoot_length": 'median',  #compute the median hindfoot length
    "weight": 'mean'}             #compute the mean weight
#Apply the dictionary
survey_df.groupby('sex').agg(aggFuncs)
# Out:
#       year             hindfoot_length     weight
#      count   min   max          median       mean
# sex
# F    15690  1977  2002            27.0  42.170555
# M    17348  1977  2002            34.0  42.995379

# %% [markdown]
# ## 4. Transforming data with pivot tables
# And finally, we can transform our data via pivot tables. In this operation, we take two categorical values in our data set, creating row labels with one and column names with the other.

# %%
survey_df.pivot_table(
    values = 'weight',
    index = 'month',
    columns= 'species_id',
    aggfunc ='mean'
).fillna(-1).T.style.background_gradient(cmap = 'YlGnBu')
# Out:
# <style type="text/css">
# #T_76098_row0_col0, #T_76098_row0_col10, #T_76098_row0_col11, #T_76098_row10_col8, #T_76098_row10_col9, #T_76098_row19_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_76098_row0_col1, #T_76098_row10_col3, #T_76098_row10_col5, #T_76098_row10_col7, #T_76098_row18_col0, #T_76098_row18_col1 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_76098_row0_col2, #T_76098_row10_col0, #T_76098_row10_col1, #T_76098_row10_col2, #T_76098_row10_col10, #T_76098_row10_col11 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_76098_row0_col3, #T_76098_row0_col4, #T_76098_row10_col4, #T_76098_row10_col6, #T_76098_row18_col2, #T_76098_row18_col10, #T_76098_row18_col11, #T_76098_row20_col1 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_76098_row0_col5, #T_76098_row0_col7 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_76098_row0_col6, #T_76098_row15_col0, #T_76098_row17_col3, #T_76098_row17_col4, #T_76098_row17_col10 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_76098_row0_col8, #T_76098_row18_col9, #T_76098_row19_col11 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_76098_row0_col9 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_76098_row1_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_76098_row1_col1, #T_76098_row1_col11, #T_76098_row11_col4, #T_76098_row23_col5 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_76098_row1_col2 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_76098_row1_col3 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_76098_row1_col4, #T_76098_row23_col10 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_76098_row1_col5, #T_76098_row2_col9 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_76098_row1_col6 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_76098_row1_col7, #T_76098_row2_col1, #T_76098_row23_col2 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_76098_row1_col8 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_76098_row1_col9 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_76098_row1_col10 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_76098_row2_col0 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_76098_row2_col2, #T_76098_row2_col11, #T_76098_row23_col1 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_76098_row2_col3, #T_76098_row2_col7, #T_76098_row21_col2, #T_76098_row23_col11 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_76098_row2_col4, #T_76098_row2_col6 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_76098_row2_col5, #T_76098_row21_col11 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_76098_row2_col8 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_76098_row2_col10 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_76098_row3_col0 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_76098_row3_col1 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_76098_row3_col2 {
#   background-color: #1f78b4;
#   color: #f1f1f1;
# }
# #T_76098_row3_col3, #T_76098_row3_col8 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_76098_row3_col4, #T_76098_row3_col7 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_76098_row3_col5 {
#   background-color: #2354a3;
#   color: #f1f1f1;
# }
# #T_76098_row3_col6 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_76098_row3_col9 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_76098_row3_col10 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_76098_row3_col11 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_76098_row4_col0, #T_76098_row4_col1, #T_76098_row4_col2, #T_76098_row4_col3, #T_76098_row4_col4, #T_76098_row4_col5, #T_76098_row4_col6, #T_76098_row4_col7, #T_76098_row4_col8, #T_76098_row4_col9, #T_76098_row4_col10, #T_76098_row4_col11 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_76098_row5_col0, #T_76098_row8_col11, #T_76098_row11_col11 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_76098_row5_col1, #T_76098_row5_col8, #T_76098_row8_col0 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_76098_row5_col2, #T_76098_row8_col8, #T_76098_row11_col2, #T_76098_row11_col3 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_76098_row5_col3, #T_76098_row11_col6 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_76098_row5_col4, #T_76098_row5_col6 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_76098_row5_col5 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_76098_row5_col7, #T_76098_row8_col5 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_76098_row5_col9, #T_76098_row11_col1 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_76098_row5_col10, #T_76098_row5_col11, #T_76098_row6_col3, #T_76098_row6_col4, #T_76098_row11_col0 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_76098_row6_col0, #T_76098_row13_col3, #T_76098_row13_col10, #T_76098_row14_col8, #T_76098_row20_col3 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_76098_row6_col1, #T_76098_row6_col11, #T_76098_row7_col8, #T_76098_row9_col2, #T_76098_row15_col4 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_76098_row6_col2, #T_76098_row6_col8, #T_76098_row7_col7, #T_76098_row12_col5, #T_76098_row14_col4 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_76098_row6_col5, #T_76098_row6_col6 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_76098_row6_col7 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_76098_row6_col9, #T_76098_row6_col10 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_76098_row7_col0, #T_76098_row7_col1, #T_76098_row7_col2, #T_76098_row7_col3, #T_76098_row7_col5, #T_76098_row7_col9, #T_76098_row7_col10, #T_76098_row7_col11, #T_76098_row11_col5, #T_76098_row12_col0, #T_76098_row12_col1, #T_76098_row12_col2, #T_76098_row12_col4, #T_76098_row12_col7, #T_76098_row12_col10, #T_76098_row12_col11, #T_76098_row13_col5, #T_76098_row13_col7, #T_76098_row16_col0, #T_76098_row16_col2, #T_76098_row16_col3, #T_76098_row16_col4, #T_76098_row16_col5, #T_76098_row16_col6, #T_76098_row16_col7, #T_76098_row16_col8, #T_76098_row16_col9, #T_76098_row16_col10, #T_76098_row16_col11, #T_76098_row17_col7, #T_76098_row19_col0, #T_76098_row19_col2, #T_76098_row19_col3, #T_76098_row19_col4, #T_76098_row19_col5, #T_76098_row19_col7, #T_76098_row19_col8, #T_76098_row19_col9, #T_76098_row19_col10, #T_76098_row20_col0, #T_76098_row20_col2, #T_76098_row20_col4, #T_76098_row20_col5, #T_76098_row20_col6, #T_76098_row20_col7, #T_76098_row20_col8, #T_76098_row20_col9, #T_76098_row20_col10, #T_76098_row20_col11, #T_76098_row21_col8, #T_76098_row21_col9, #T_76098_row24_col0, #T_76098_row24_col1, #T_76098_row24_col2, #T_76098_row24_col3, #T_76098_row24_col4, #T_76098_row24_col6, #T_76098_row24_col7, #T_76098_row24_col8, #T_76098_row24_col10, #T_76098_row24_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_76098_row7_col4, #T_76098_row9_col8, #T_76098_row9_col9, #T_76098_row9_col10, #T_76098_row14_col0, #T_76098_row14_col10, #T_76098_row15_col3 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_76098_row7_col6, #T_76098_row9_col5, #T_76098_row9_col7, #T_76098_row11_col9, #T_76098_row12_col6, #T_76098_row14_col3, #T_76098_row14_col7 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_76098_row8_col1, #T_76098_row8_col9, #T_76098_row8_col10, #T_76098_row11_col8, #T_76098_row11_col10 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_76098_row8_col2, #T_76098_row8_col7 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_76098_row8_col3 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_76098_row8_col4, #T_76098_row23_col0 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_76098_row8_col6 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_76098_row9_col0, #T_76098_row9_col1, #T_76098_row9_col11, #T_76098_row13_col0, #T_76098_row13_col6, #T_76098_row14_col2, #T_76098_row14_col9, #T_76098_row14_col11 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_76098_row9_col3, #T_76098_row9_col4, #T_76098_row9_col6, #T_76098_row14_col5, #T_76098_row14_col6 {
#   background-color: #e5f5b2;
#   color: #000000;
